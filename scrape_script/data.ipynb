# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_jap = pd.read_csv('/content/drive/MyDrive/Cloud Computing/HW1/Japanese.csv')

# %%
print(df_jap)
# Out:
#                  Japanese_name  \
# 0        Saketumi Asian Bistro
# 1                    Bamboo Ya
# 2                         Raku
# 3                      Benemon
# 4                      Okonomi
# ..                         ...
# 320               Sake No Hana
# 321                       noda
# 322                Sushi Nikko
# 323  Hiyake Omakase - Brooklyn
# 324             Tamashii Ramen
#
#                                           Japanese_url  \
# 0    https://www.yelp.com/adredir?ad_business_id=8J...
# 1    https://www.yelp.com/adredir?ad_business_id=m4...
# 2    https://www.yelp.com/biz/raku-new-york-7?osq=J...
# 3    https://www.yelp.com/biz/benemon-new-york?osq=...
# 4    https://www.yelp.com/biz/okonomi-brooklyn?osq=...
# ..                                                 ...
# 320  https://www.yelp.com/biz/sake-no-hana-new-york...
# 321  https://www.yelp.com/biz/noda-new-york?osq=Jap...
# 322  https://www.yelp.com/biz/sushi-nikko-queens?os...
# ...

# %%
df_jap = df_jap[df_jap['Japanese_Address'].notna()]

# %%
print(df_jap)
# Out:
#                  Japanese_name  \
# 2                         Raku
# 3                      Benemon
# 4                      Okonomi
# 6          DOMODOMO - New York
# 9                       Kimura
# ..                         ...
# 315                   Chikurin
# 316            TJ Asian Bistro
# 318                         NR
# 319  Zurutto Ramen & Gyoza Bar
# 321                       noda
#
#                                           Japanese_url  \
# 2    https://www.yelp.com/biz/raku-new-york-7?osq=J...
# 3    https://www.yelp.com/biz/benemon-new-york?osq=...
# 4    https://www.yelp.com/biz/okonomi-brooklyn?osq=...
# 6    https://www.yelp.com/biz/domodomo-new-york-new...
# 9    https://www.yelp.com/biz/kimura-new-york?osq=J...
# ..                                                 ...
# 315  https://www.yelp.com/biz/chikurin-brooklyn-2?o...
# 316  https://www.yelp.com/biz/tj-asian-bistro-woods...
# 318  https://www.yelp.com/biz/nr-new-york-4?osq=Jap...
# ...

# %%
df_jap["category"] = "Japanese"

# %%
print(df_jap)
# Out:
#                  Japanese_name  \
# 2                         Raku
# 3                      Benemon
# 4                      Okonomi
# 6          DOMODOMO - New York
# 9                       Kimura
# ..                         ...
# 315                   Chikurin
# 316            TJ Asian Bistro
# 318                         NR
# 319  Zurutto Ramen & Gyoza Bar
# 321                       noda
#
#                                           Japanese_url  \
# 2    https://www.yelp.com/biz/raku-new-york-7?osq=J...
# 3    https://www.yelp.com/biz/benemon-new-york?osq=...
# 4    https://www.yelp.com/biz/okonomi-brooklyn?osq=...
# 6    https://www.yelp.com/biz/domodomo-new-york-new...
# 9    https://www.yelp.com/biz/kimura-new-york?osq=J...
# ..                                                 ...
# 315  https://www.yelp.com/biz/chikurin-brooklyn-2?o...
# 316  https://www.yelp.com/biz/tj-asian-bistro-woods...
# 318  https://www.yelp.com/biz/nr-new-york-4?osq=Jap...
# ...

# %%
df_jap.rename(columns = {'Japanese_name':'name'}, inplace = True)
df_jap.rename(columns = {'Japanese_url':'url'}, inplace = True)
df_jap.rename(columns = {'Japanese_Address':'address'}, inplace = True)

# %%
df_jap
# Out:
#                           name  \
# 2                         Raku
# 3                      Benemon
# 4                      Okonomi
# 6          DOMODOMO - New York
# 9                       Kimura
# ..                         ...
# 315                   Chikurin
# 316            TJ Asian Bistro
# 318                         NR
# 319  Zurutto Ramen & Gyoza Bar
# 321                       noda
#
#                                                    url  \
# 2    https://www.yelp.com/biz/raku-new-york-7?osq=J...
# 3    https://www.yelp.com/biz/benemon-new-york?osq=...
# 4    https://www.yelp.com/biz/okonomi-brooklyn?osq=...
# 6    https://www.yelp.com/biz/domodomo-new-york-new...
# 9    https://www.yelp.com/biz/kimura-new-york?osq=J...
# ..                                                 ...
# 315  https://www.yelp.com/biz/chikurin-brooklyn-2?o...
# 316  https://www.yelp.com/biz/tj-asian-bistro-woods...
# 318  https://www.yelp.com/biz/nr-new-york-4?osq=Jap...
# ...

# %%
df_ch = pd.read_csv('/content/drive/MyDrive/Cloud Computing/HW1/chinese.csv')
df_ch
# Out:
#                  selection1_name  \
# 0      A-Roll Grill Chicken Feet
# 1                  M Noodle Shop
# 2                       Ke Zhang
# 3          Saketumi Asian Bistro
# 4                  Dumpling Town
# ..                           ...
# 329                    Charm Kao
# 330                 Shanghai Lee
# 331  Chinese Musician Restaurant
# 332              Hop Lee Kitchen
# 333              Dimmer & Summer
#
#                                         selection1_url selection1_address
# 0    https://www.yelp.com/adredir?ad_business_id=4_...                NaN
# 1    https://www.yelp.com/adredir?ad_business_id=9K...                NaN
# 2    https://www.yelp.com/adredir?ad_business_id=1-...                NaN
# 3    https://www.yelp.com/adredir?ad_business_id=8J...                NaN
# 4    https://www.yelp.com/adredir?ad_business_id=Cs...                NaN
# ..                                                 ...                ...
# ...

# %%
df_ch = df_ch[df_ch['selection1_address'].notna()]
df_ch["category"] = "Chinese"

df_ch.rename(columns = {'selection1_name':'name'}, inplace = True)
df_ch.rename(columns = {'selection1_url':'url'}, inplace = True)
df_ch.rename(columns = {'selection1_address':'address'}, inplace = True)

df_ch
# Out:
# <ipython-input-28-a883de7f4361>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ch["category"] = "Chinese"
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                             name  \
# 5               Shu Jiao Fu Zhou
# 6                 Joe’s Shanghai
# 7                  Wah Fung No 1
# 8                     Chow House
# 9                       Antidote
# ..                           ...
# 326      Good Chinese Restaurant
# ...

# %%
df_it = pd.read_csv('/content/drive/MyDrive/Cloud Computing/HW1/Italian.csv')
df_it
# Out:
#                    Italian_name  \
# 0              Papa Johns Pizza
# 1             Valentino’s Pizza
# 2                     Da Andrea
# 3                    Olio e Più
# 4                      Rubirosa
# ..                          ...
# 320                       Canto
# 321                    Bernie’s
# 322               Belli Osteria
# 323               La Casa Bella
# 324  Scottadito Osteria Toscana
#
#                                            Italian_url  \
# 0    https://www.yelp.com/adredir?ad_business_id=0W...
# 1    https://www.yelp.com/adredir?ad_business_id=qA...
# 2    https://www.yelp.com/biz/da-andrea-new-york?os...
# 3    https://www.yelp.com/biz/olio-e-pi%C3%B9-new-y...
# 4    https://www.yelp.com/biz/rubirosa-new-york-2?o...
# ..                                                 ...
# 320  https://www.yelp.com/biz/canto-new-york?osq=It...
# 321  https://www.yelp.com/biz/bernies-brooklyn?osq=...
# 322  https://www.yelp.com/biz/belli-osteria-brookly...
# ...

# %%
df_it = df_it[df_it['Italian_address'].notna()]
df_it["category"] = "Italian"

df_it.rename(columns = {'Italian_name':'name'}, inplace = True)
df_it.rename(columns = {'Italian_url':'url'}, inplace = True)
df_it.rename(columns = {'Italian_address':'address'}, inplace = True)

df_it
# Out:
# <ipython-input-30-7ab9a8d81b50>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_it["category"] = "Italian"
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                            name  \
# 2                     Da Andrea
# 4                      Rubirosa
# 5    Paesano of Mulberry Street
# 6                      L’Artusi
# 7         Lillo Cucina Italiana
# ..                          ...
# 318         Adrienne’s Pizzabar
# ...

# %%
df_final = pd.concat([df_jap, df_ch, df_it])

# %%
df_final
# Out:
#                     name                                                url  \
# 2                   Raku  https://www.yelp.com/biz/raku-new-york-7?osq=J...
# 3                Benemon  https://www.yelp.com/biz/benemon-new-york?osq=...
# 4                Okonomi  https://www.yelp.com/biz/okonomi-brooklyn?osq=...
# 6    DOMODOMO - New York  https://www.yelp.com/biz/domodomo-new-york-new...
# 9                 Kimura  https://www.yelp.com/biz/kimura-new-york?osq=J...
# ..                   ...                                                ...
# 318  Adrienne’s Pizzabar  https://www.yelp.com/biz/adriennes-pizzabar-ne...
# 319              Cotenna  https://www.yelp.com/biz/cotenna-new-york?osq=...
# 321             Bernie’s  https://www.yelp.com/biz/bernies-brooklyn?osq=...
# 322        Belli Osteria  https://www.yelp.com/biz/belli-osteria-brookly...
# 323        La Casa Bella  https://www.yelp.com/biz/la-casa-bella-brookly...
#
#                        address  category
# ...

# %%
df_final.to_csv('/content/drive/MyDrive/Cloud Computing/HW1/Japanese.csv', encoding='utf-8', index=False)
